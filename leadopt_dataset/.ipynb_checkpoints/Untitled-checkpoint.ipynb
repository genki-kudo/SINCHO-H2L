# %%
import subprocess

with open('set.txt','r')as data:
    for i in data:
        #subprocess.call(['wget', 'https://files.rcsb.org/download/'+i+'.pdb'])
        print('wget', 'https://files.rcsb.org/download/'+i+'.pdb')
# Out:
# --2022-06-30 17:29:56--  https://files.rcsb.org/download/7JYT%0A.pdb
# files.rcsb.org (files.rcsb.org) をDNSに問いあわせています... 132.249.210.134
# files.rcsb.org (files.rcsb.org)|132.249.210.134|:443 に接続しています... 接続しました。
# HTTP による接続要求を送信しました、応答を待っています... 404 Not Found
# 2022-06-30 17:29:57 エラー 404: Not Found。
#
# --2022-06-30 17:29:57--  https://files.rcsb.org/download/6TPD%0A.pdb
# files.rcsb.org (files.rcsb.org) をDNSに問いあわせています... 132.249.210.134
# files.rcsb.org (files.rcsb.org)|132.249.210.134|:443 に接続しています... 接続しました。
# HTTP による接続要求を送信しました、応答を待っています... 404 Not Found
# 2022-06-30 17:29:57 エラー 404: Not Found。
#
# --2022-06-30 17:29:57--  https://files.rcsb.org/download/6YYO%0A.pdb
# files.rcsb.org (files.rcsb.org) をDNSに問いあわせています... 132.249.210.134
# files.rcsb.org (files.rcsb.org)|132.249.210.134|:443 に接続しています... 接続しました。
# HTTP による接続要求を送信しました、応答を待っています... 404 Not Found
# 2022-06-30 17:29:58 エラー 404: Not Found。
#
# --2022-06-30 17:29:58--  https://files.rcsb.org/download/6SQ5%0A.pdb
# ...
