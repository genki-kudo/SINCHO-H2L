# %%
import subprocess

with open('set.txt','r')as data:
    for i in data:
        pdb = str(i[:4])
        print(pdb)
        subprocess.call(['wget', 'https://files.rcsb.org/download/'+pdb+'.pdb'])
# Out:
# 7JYT
# --2022-06-30 17:32:18--  https://files.rcsb.org/download/7JYT.pdb
# files.rcsb.org (files.rcsb.org) をDNSに問いあわせています... 132.249.210.134
# files.rcsb.org (files.rcsb.org)|132.249.210.134|:443 に接続しています... 接続しました。
# HTTP による接続要求を送信しました、応答を待っています... 200 OK
# 長さ: 特定できません [application/octet-stream]
# `7JYT.pdb' に保存中
#
#      0K .......... .......... .......... .......... ..........  140K
#     50K .......... .......... .......... .......... ..........  144K
#    100K .......... .......... .......... .......... ..........  140K
#    150K .......... .......... .......... .......... ..........  214K
#    200K .......... .......... .......... .......... ..........  140K
#    250K .......... .......... .......... .......... ..........  213K
#    300K .......... .......... .......... .......... ..........  420K
#    350K .......... .......... .......... .......... ..          184K=2.2s
#
# 2022-06-30 17:32:20 (175 KB/s) - `7JYT.pdb' へ保存終了 [402003]
#
# ...
